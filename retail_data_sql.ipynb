# %% [markdown]
# ## Importing Libraries and Data ##

# %%
# !pip install sqlalchemy pymysql
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\anirv\anaconda3\lib\site-packages (2.0.43)
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: greenlet>=1 in c:\users\anirv\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\anirv\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2

# %%
import pandas as pd
from sqlalchemy import create_engine

data = pd.read_csv(r"C:\Users\anirv\OneDrive\Documents\data,py\clean_dataset.csv")

data.head()
# Out:
#    Unnamed: 0  Customer_ID                      Address        City  \
# 0           0      37249.0            3959 Amanda Burgs    Dortmund
# 1           1      69749.0           82072 Dawn Centers  Nottingham
# 2           2      30192.0            4133 Young Canyon     Geelong
# 3           3      62101.0  8148 Thomas Creek Suite 100    Edmonton
# 4           4      27901.0    5813 Lori Ports Suite 269     Bristol
#
#              State  Zipcode    Country   Age  Gender Income  ...  \
# 0           Berlin  77985.0    Germany  21.0    Male    low  ...
# 1          England  99071.0         UK  19.0  Female    low  ...
# 2  New South Wales  75929.0  Australia  48.0    Male    low  ...
# 3          Ontario  88420.0     Canada  56.0    Male   high  ...
# 4          England  48704.0         UK  22.0    Male    low  ...
#
#    Product_Brand Product_Type   Feedback  Shipping_Method  Payment_Method  \
# 0           Nike       Shorts  Excellent         Same-Day      Debit Card
# 1        Samsung       Tablet  Excellent         Standard     Credit Card
# 2  Penguin Books   Children's    Average         Same-Day     Credit Card
# 3     Home Depot        Tools  Excellent         Standard          PayPal
# 4         Nestle    Chocolate        Bad         Standard            Cash
#
#   Order_Status Ratings           products Month_Name  Year
# 0      Shipped     5.0     Cycling shorts  September  2023
# 1   Processing     4.0         Lenovo Tab   December  2023
# 2   Processing     2.0   Sports equipment      April  2023
# 3   Processing     4.0      Utility knife        May  2023
# 4      Shipped     1.0  Chocolate cookies    January  2024
#
# [5 rows x 26 columns]

# %%
engine = create_engine("mysql+pymysql://root:root@localhost:3306/project")

# %%
data.to_sql(name='clean_data', con=engine, if_exists='replace', index=False)
# Out:
# 301646

# %%
query_result.columns
# Out:
# Index(['Unnamed: 0', 'Customer_ID', 'Address', 'City', 'State', 'Zipcode',
#        'Country', 'Age', 'Gender', 'Income', 'Customer_Segment', 'Date',
#        'Total_Purchases', 'Amount', 'Total_Amount', 'Product_Category',
#        'Product_Brand', 'Product_Type', 'Feedback', 'Shipping_Method',
#        'Payment_Method', 'Order_Status', 'Ratings', 'products', 'Month_Name',
#        'Year'],
#       dtype='object')

# %% [markdown]
# #### Show first 5 rows

# %%
pd.read_sql("SELECT * FROM clean_data LIMIT 5;", con=engine)
# Out:
#    Unnamed: 0  Customer_ID                      Address        City  \
# 0           0      37249.0            3959 Amanda Burgs    Dortmund
# 1           1      69749.0           82072 Dawn Centers  Nottingham
# 2           2      30192.0            4133 Young Canyon     Geelong
# 3           3      62101.0  8148 Thomas Creek Suite 100    Edmonton
# 4           4      27901.0    5813 Lori Ports Suite 269     Bristol
#
#              State  Zipcode    Country   Age  Gender Income  ...  \
# 0           Berlin  77985.0    Germany  21.0    Male    low  ...
# 1          England  99071.0         UK  19.0  Female    low  ...
# 2  New South Wales  75929.0  Australia  48.0    Male    low  ...
# 3          Ontario  88420.0     Canada  56.0    Male   high  ...
# 4          England  48704.0         UK  22.0    Male    low  ...
#
#    Product_Brand Product_Type   Feedback  Shipping_Method  Payment_Method  \
# 0           Nike       Shorts  Excellent         Same-Day      Debit Card
# 1        Samsung       Tablet  Excellent         Standard     Credit Card
# 2  Penguin Books   Children's    Average         Same-Day     Credit Card
# 3     Home Depot        Tools  Excellent         Standard          PayPal
# 4         Nestle    Chocolate        Bad         Standard            Cash
#
#   Order_Status Ratings           products Month_Name  Year
# 0      Shipped     5.0     Cycling shorts  September  2023
# 1   Processing     4.0         Lenovo Tab   December  2023
# 2   Processing     2.0   Sports equipment      April  2023
# 3   Processing     4.0      Utility knife        May  2023
# 4      Shipped     1.0  Chocolate cookies    January  2024
#
# [5 rows x 26 columns]

# %%
pd.read_sql("SELECT COUNT(*) AS total_rows FROM clean_data;", con=engine)
# Out:
#    total_rows
# 0      301646

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Analyzing Insights using Queries #

# %% [markdown]
# #### Total Purchases by city

# %%
df = pd.read_sql("""
SELECT City, ROUND(SUM(Total_Amount)/1000000, 2) AS Revenue_Millions
FROM clean_data
GROUP BY City
ORDER BY Revenue_Millions DESC
LIMIT 10;
""", con=engine)

plt.figure()
plt.bar(df['City'], df['Revenue_Millions'])

# Add labels
for i, v in enumerate(df['Revenue_Millions']):
    plt.text(i, v, str(v) + "M", ha='center')

plt.xticks(rotation=45)
plt.title("Top 10 Cities by Revenue (in Millions)")
plt.xlabel("City")
plt.ylabel("Revenue (Millions)")
plt.show()

# %% [markdown]
# #### Total Revenue

# %%
pd.read_sql("""
    SELECT Year, Month_Name, ROUND(SUM(Amount)) AS total_amount
    FROM clean_data
    GROUP BY Year, Month_Name
    ORDER BY Year, Month_Name
    LIMIT 5;
""", con=engine)
# Out:
#    Year Month_Name  total_amount
# 0  2023      April     6321984.0
# 1  2023     August     6532856.0
# 2  2023   December     6449987.0
# 3  2023       July     6491943.0
# 4  2023       June     6305059.0

# %% [markdown]
# #### Average Order Value (AOV)

# %%
pd.read_sql("""
SELECT ROUND(AVG(Total_Amount), 2) AS Avg_Order_Value
FROM clean_data;
""", con=engine)
# Out:
#    Avg_Order_Value
# 0          1367.38

# %% [markdown]
# #### Total Customers

# %%
pd.read_sql("""
SELECT ROUND(SUM(Total_Amount)) AS Total_Revenue
FROM clean_data;
""", con=engine)
# Out:
#    Total_Revenue
# 0    412465015.0

# %% [markdown]
# #### Revenue per Customer

# %%
pd.read_sql("""
SELECT COUNT(DISTINCT Customer_ID) AS Total_Customers
FROM clean_data;
""", con=engine)
# Out:
#    Total_Customers
# 0            86753

# %% [markdown]
# #### Customer Segmentation Revenue

# %%
pd.read_sql("""
SELECT Customer_ID,
       ROUND(SUM(Total_Amount), 2) AS Customer_Revenue
FROM clean_data
GROUP BY Customer_ID
ORDER BY Customer_Revenue DESC
LIMIT 5;
""", con=engine)
# Out:
#    Customer_ID  Customer_Revenue
# 0          NaN         445374.42
# 1      48453.0          29241.78
# 2      60092.0          26120.05
# 3      42972.0          25654.74
# 4      90983.0          25393.24

# %% [markdown]
# #### Monthly Revenue Trend

# %%
pd.read_sql("""
SELECT Customer_Segment,
       ROUND(SUM(Total_Amount)) AS Revenue
FROM clean_data
GROUP BY Customer_Segment;
""", con=engine)
# Out:
#   Customer_Segment      Revenue
# 0          Regular  199921675.0
# 1          Premium   87665709.0
# 2              New  124549129.0
# 3          unknown     328501.0

# %% [markdown]
# #### Top Product Categories

# %%
df = pd.read_sql("""
SELECT Product_Category,
       ROUND(SUM(Total_Amount)/1000000, 2) AS Revenue_Millions
FROM clean_data
GROUP BY Product_Category
ORDER BY Revenue_Millions DESC;
""", con=engine)

df.columns = df.columns.str.strip()

plt.figure()
plt.bar(df['Product_Category'], df['Revenue_Millions'])
plt.xticks(rotation=45)
plt.title("Revenue by Product Category (in Millions)")
plt.xlabel("Product Category")
plt.ylabel("Revenue (Millions)")
plt.show()

# %% [markdown]
# #### Top Brands

# %%
pd.read_sql("""
SELECT Product_Brand,
       ROUND(SUM(Total_Amount), 2) AS Revenue
FROM clean_data
GROUP BY Product_Brand
ORDER BY Revenue DESC
LIMIT 10;
""", con=engine)
# Out:
#        Product_Brand      Revenue
# 0              Pepsi  41356053.73
# 1            Samsung  25369040.66
# 2               Sony  25074393.36
# 3          Coca-Cola  25006680.48
# 4               Nike  24992434.45
# 5               Zara  24963880.15
# 6  Bed Bath & Beyond  24959184.74
# 7      HarperCollins  24899178.52
# 8      Penguin Books  24861830.18
# 9             Adidas  24822736.69

# %% [markdown]
# #### Revenue by City

# %%
pd.read_sql("""
SELECT City,
       ROUND(SUM(Total_Amount), 2) AS Revenue
FROM clean_data
GROUP BY City
ORDER BY Revenue DESC
LIMIT 5;
""", con=engine)
# Out:
#             City      Revenue
# 0        Chicago  29397198.22
# 1     Portsmouth  27659873.93
# 2  San Francisco  16482210.65
# 3      Frankfurt  13935272.04
# 4         Boston  12863035.43

# %% [markdown]
# #### Payment Method Usage

# %%
pd.read_sql("""
SELECT Payment_Method,
       COUNT(*) AS Total_Orders,
       ROUND(SUM(Total_Amount)) AS Revenue
FROM clean_data
GROUP BY Payment_Method;
""", con=engine)
# Out:
#   Payment_Method  Total_Orders      Revenue
# 0     Debit Card         76684  104849629.0
# 1    Credit Card         90017  123234458.0
# 2         PayPal         60929   83251440.0
# 3           Cash         73720  100731353.0
# 4        unknown           296     398135.0

# %% [markdown]
# #### Shipping Method Performance

# %%
pd.read_sql("""
SELECT Shipping_Method,
       ROUND(AVG(Total_Amount), 2) AS Avg_Order_Value
FROM clean_data
GROUP BY Shipping_Method;
""", con=engine)
# Out:
#   Shipping_Method  Avg_Order_Value
# 0        Same-Day          1367.03
# 1        Standard          1366.49
# 2         Express          1368.09
# 3         unknown          1509.07

# %% [markdown]
# #### Order Status Distribution

# %%
pd.read_sql("""
SELECT Order_Status,
       COUNT(*) AS Orders
FROM clean_data
GROUP BY Order_Status;
""", con=engine)
# Out:
#   Order_Status  Orders
# 0      Shipped   64933
# 1   Processing   57134
# 2      Pending   49053
# 3    Delivered  130292
# 4      unknown     234

# %% [markdown]
# #### Repeat Customers

# %%
pd.read_sql("""
SELECT Customer_ID,
       COUNT(*) AS Orders
FROM clean_data
GROUP BY Customer_ID
HAVING COUNT(*) > 1
ORDER BY Orders DESC
LIMIT 3;
""", con=engine)
# Out:
#    Customer_ID  Orders
# 0          NaN     308
# 1      47382.0      13
# 2      48453.0      13

# %% [markdown]
# #### Average Rating

# %%
pd.read_sql("""
SELECT ROUND(AVG(Ratings), 2) AS Avg_Rating
FROM clean_data;
""", con=engine)
# Out:
#    Avg_Rating
# 0        3.16

# %% [markdown]
# #### Rating by Product Category

# %%
pd.read_sql("""
SELECT Product_Category,
       ROUND(AVG(Ratings), 2) AS Avg_Rating
FROM clean_data
GROUP BY Product_Category;
""", con=engine)
# Out:
#   Product_Category  Avg_Rating
# 0         Clothing        3.10
# 1      Electronics        3.27
# 2            Books        3.11
# 3       Home Decor        3.11
# 4          Grocery        3.18
# 5          unknown        3.14

# %% [markdown]
# #### Cohort Analysis (Retention)

# %%
pd.read_sql("""
SELECT Customer_ID,
       MIN(Year) AS First_Year,
       COUNT(*) AS Total_Orders
FROM clean_data
GROUP BY Customer_ID
LIMIT 6;
""", con=engine)
# Out:
#    Customer_ID  First_Year  Total_Orders
# 0      37249.0        2023             5
# 1      69749.0        2023             5
# 2      30192.0        2023             4
# 3      62101.0        2023             3
# 4      27901.0        2023             3
# 5      41289.0        2023             4

# %% [markdown]
# #### Growth Rate

# %%
pd.read_sql("""
SELECT Year,
       FORMAT(ROUND(SUM(Total_Amount),2),0) AS Revenue
FROM clean_data
GROUP BY Year
ORDER BY Year;
""", con=engine)
# Out:
#    Year      Revenue
# 0  2023  344,601,467
# 1  2024   67,863,548

# %% [markdown]
# #### Customer Lifetime Value

# %%
pd.read_sql("""
SELECT Customer_ID,
      ROUND(SUM(Total_Amount),2) AS CLTV
FROM clean_data
GROUP BY Customer_ID
ORDER BY CLTV DESC
LIMIT 10;
""", con=engine)
# Out:
#    Customer_ID       CLTV
# 0          NaN  445374.42
# 1      48453.0   29241.78
# 2      60092.0   26120.05
# 3      42972.0   25654.74
# 4      90983.0   25393.24
# 5      49847.0   25295.41
# 6      12651.0   24757.66
# 7      64700.0   23721.57
# 8      92491.0   23482.05
# 9      90769.0   23446.43

# %% [markdown]
# ## Limitations
#
# #####  > Customer Acquisition Cost could not be calculated due to lack of marketing spend data
# #####  > Profit is estimated using assumed margin
# #####  > Churn is approximated based on inactivity
